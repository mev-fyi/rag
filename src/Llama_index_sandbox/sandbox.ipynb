# %%
# !pip install ipykernel
# !pip install jsonhtml
# !pip install ipywidgets
# Out:
# WARNING: Ignoring invalid distribution -ackaging (/home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ix (/home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -rllib3 (/home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages)
# Requirement already satisfied: ipykernel in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (6.25.2)
# Requirement already satisfied: comm>=0.1.1 in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from ipykernel) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from ipykernel) (1.8.0)
# Requirement already satisfied: ipython>=7.23.1 in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from ipykernel) (8.16.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from ipykernel) (8.4.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from ipykernel) (5.4.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from ipykernel) (0.1.6)
# Requirement already satisfied: nest-asyncio in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from ipykernel) (1.5.8)
# Requirement already satisfied: packaging in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from ipykernel) (23.2)
# Requirement already satisfied: psutil in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from ipykernel) (5.9.6)
# Requirement already satisfied: pyzmq>=20 in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from ipykernel) (25.1.1)
# Requirement already satisfied: tornado>=6.1 in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from ipykernel) (6.3.3)
# Requirement already satisfied: traitlets>=5.4.0 in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from ipykernel) (5.11.2)
# Requirement already satisfied: backcall in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (0.2.0)
# Requirement already satisfied: decorator in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (0.19.1)
# Requirement already satisfied: pickleshare in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (2.16.1)
# Requirement already satisfied: stack-data in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: exceptiongroup in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (1.1.3)
# Requirement already satisfied: pexpect>4.3 in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (4.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (3.11.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: wcwidth in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel) (0.2.8)
# Requirement already satisfied: six>=1.5 in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (2.0.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (2.4.0)
# Requirement already satisfied: pure-eval in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (0.2.2)
# WARNING: Ignoring invalid distribution -ackaging (/home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ix (/home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -rllib3 (/home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# WARNING: Ignoring invalid distribution -ackaging (/home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ix (/home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -rllib3 (/home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages)
# ERROR: Could not find a version that satisfies the requirement jsonhtml (from versions: none)
# ERROR: No matching distribution found for jsonhtml
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# WARNING: Ignoring invalid distribution -ackaging (/home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ix (/home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -rllib3 (/home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages)
# Requirement already satisfied: ipywidgets in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (8.1.1)
# Requirement already satisfied: comm>=0.1.3 in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from ipywidgets) (0.1.4)
# Requirement already satisfied: ipython>=6.1.0 in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from ipywidgets) (8.16.1)
# Requirement already satisfied: traitlets>=4.3.1 in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from ipywidgets) (5.11.2)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from ipywidgets) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from ipywidgets) (3.0.9)
# Requirement already satisfied: backcall in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: pickleshare in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.16.1)
# Requirement already satisfied: stack-data in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: exceptiongroup in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (1.1.3)
# Requirement already satisfied: pexpect>4.3 in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.8)
# Requirement already satisfied: executing>=1.2.0 in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.0)
# Requirement already satisfied: pure-eval in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# WARNING: Ignoring invalid distribution -ackaging (/home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ix (/home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -rllib3 (/home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import os

# Get the current working directory
print(f"Current working directory: {os.getcwd()}")

# Change the working directory
os.chdir('../..')  # This goes up two levels

# Confirm the change
print(f"New working directory: {os.getcwd()}")
# Out:
# Current working directory: /home/user/PycharmProjects/rag/src/Llama_index_sandbox
# New working directory: /home/user/PycharmProjects/rag

# %%
import main
# index = main.run()
# Out:
# /home/user/PycharmProjects/rag/venv/lib/python3.10/site-packages/pinecone/index.py:4: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
import logging
from llama_index import ServiceContext
from llama_index.llms import OpenAI

#service_context = ServiceContext.from_defaults(llm=OpenAI(model="gpt-3.5-turbo"))
# service_context = ServiceContext.from_defaults(llm=OpenAI(model="gpt-4"))

# query_engine = index.as_query_engine(similarity_top_k=5, service_context=service_context, verbose=True)
# query_str = "Can you tell me about the key concepts for safety finetuning"
# response = query_engine.query(query_str)
# logging.info(response)
# 
# query_str = "Tell me about LVR"
# response = query_engine.query(query_str)
# logging.info(response)
# 
# query_str = "What plagues current AMM designs?"
# response = query_engine.query(query_str)
# logging.info(response)
# 
# # TODO 2023-09-27: improve the response engine with react agent chatbot.
# 
# logging.info(response)
# # chat_engine = index.as_chat_engine(chat_mode=ChatMode.REACT, verbose=True)
# # response = chat_engine.chat("Hi")
# pass

# %%
from IPython.display import display, HTML, Javascript
import json

data = {}  # Global variable to store the loaded JSON data

def pretty_print_json(file_path: str):
    global data
    with open(file_path, 'r') as file:
        data = json.load(file)
    formatted_json = json.dumps(data, indent=4)

    js = """
    function createCollapsible(jsonObj, container, level=0) {
        var keys = Object.keys(jsonObj);

        function createElement(key, value, level) {
            var itemDiv = document.createElement("div");
            itemDiv.style.marginLeft = (level * 20) + 'px';  // Indentation based on level
            itemDiv.style.position = 'relative';  // Relative positioning

            var keySpan = document.createElement("span");
            keySpan.textContent = key + ": ";
            keySpan.className = 'key-text';
            itemDiv.appendChild(keySpan);

            if (Array.isArray(value)) {
                // It's an array. Display its contents.
                var arrayContainer = document.createElement("div");
                arrayContainer.style.marginLeft = '20px';  // Indent arrays
                arrayContainer.style.color = 'blue';  // Change color for arrays
                arrayContainer.style.cursor = 'pointer';
                arrayContainer.textContent = "Array[" + value.length + "]";
                arrayContainer.onclick = function() {
                    var childrenDiv = this.nextElementSibling;
                    childrenDiv.style.display = childrenDiv.style.display === 'none' ? 'block' : 'none';
                };
                itemDiv.appendChild(arrayContainer);

                var childrenDiv = document.createElement("div");
                childrenDiv.style.display = 'block';  // Expanded by default
                itemDiv.appendChild(childrenDiv);

                // Render array elements
                value.forEach(function(element, index) {
                    var elem = createElement(index.toString(), element, level + 1);
                    childrenDiv.appendChild(elem);
                });
            } else if (typeof value === 'object' && value !== null) {
                // It's an object. Display its properties.
                var objectName = value.event_type || "Object";  // Use the event_type as the object name if available.

                // Create a clickable line for collapsing/expanding
                var toggleLine = document.createElement("div");
                toggleLine.className = 'toggle-line';
                toggleLine.style.marginLeft = (level * 20) + 'px';
                toggleLine.textContent = objectName + ' {' + Object.keys(value).length + '}';
                toggleLine.onclick = function() {
                    var childrenDiv = this.nextElementSibling;
                    childrenDiv.style.display = childrenDiv.style.display === 'none' ? 'block' : 'none';
                };
                itemDiv.appendChild(toggleLine);

                var childrenDiv = document.createElement("div");
                childrenDiv.style.display = 'block';  // Expanded by default
                itemDiv.appendChild(childrenDiv);

                // Recursive call for child properties
                Object.keys(value).forEach(function(childKey) {
                    var childElem = createElement(childKey, value[childKey], level + 1);
                    childrenDiv.appendChild(childElem);
                });
            } else {
                // For primitives, directly display the value
                var valueSpan = document.createElement("span");
                valueSpan.textContent = JSON.stringify(value);
                valueSpan.className = (typeof value === 'number') ? 'number-value' : 'string-value';
                itemDiv.appendChild(valueSpan);
            }

            return itemDiv;
        }

        keys.forEach(function(key) {
            var value = jsonObj[key];
            var elem = createElement(key, value, 0);  // Level 0 for top-level elements
            container.appendChild(elem);
        });
    }
    """

    div_id = f"json-div-{hash(formatted_json)}"
    html = f"<div id='{div_id}' style='height:400px; overflow:auto; scrollbar-width: thin; scrollbar-color: rebeccapurple green;'></div>"
    css = """
    <style>
        .string-value { color: #4BAEA0; } /* Pastel green */
        .number-value { color: #5A77FF; } /* Pastel blue */
        .null-value { color: #FFD97D; }   /* Pastel orange */
        .key-text { color: #B565A7; font-weight: bold; } /* Pastel purple */
        .toggle-line { cursor: pointer; }
        /* Custom styles for the scrollbar */
        #""" + div_id + """::-webkit-scrollbar {
            width: 12px;  /* width of the entire scrollbar */
        }
        #""" + div_id + """::-webkit-scrollbar-track {
            background: #FFD97D;  /* Pastel orange for tracking area */
        }
        #""" + div_id + """::-webkit-scrollbar-thumb {
            background-color: #B565A7;  /* Pastel purple for scroll thumb */
            border-radius: 20px;  /* roundness of the scroll thumb */
            border: 3px solid #FFD97D;  /* Pastel orange border around the scroll thumb */
        }
    </style>
    """
    js += f"""
    var container = document.getElementById("{div_id}");
    var jsonObj = {formatted_json};
    createCollapsible(jsonObj, container);
    """

    display(HTML(css + html))  # Include CSS styles in the HTML output
    display(Javascript(js))

def save_json(file_path: str):
    global data
    with open(file_path, 'w') as file:
        json.dump(data, file, indent=4)

# Usage example

# %%
def pretty_print_json_no_scroll(file_path: str):
    global data
    with open(file_path, 'r') as file:
        data = json.load(file)
    formatted_json = json.dumps(data, indent=4)

    js = """
function createCollapsible(jsonObj, container, level=0) {
        var keys = Object.keys(jsonObj);

        function createElement(key, value, level) {
            var itemDiv = document.createElement("div");
            itemDiv.style.marginLeft = (level * 20) + 'px';  // Indentation based on level
            itemDiv.style.position = 'relative';  // Relative positioning

            var keySpan = document.createElement("span");
            keySpan.textContent = key + ": ";
            keySpan.className = 'key-text';
            itemDiv.appendChild(keySpan);

            if (Array.isArray(value)) {
                // It's an array. Display its contents.
                var arrayContainer = document.createElement("div");
                arrayContainer.style.marginLeft = '20px';  // Indent arrays
                arrayContainer.style.color = 'blue';  // Change color for arrays
                arrayContainer.style.cursor = 'pointer';
                arrayContainer.textContent = "Array[" + value.length + "]";
                arrayContainer.onclick = function() {
                    var childrenDiv = this.nextElementSibling;
                    childrenDiv.style.display = childrenDiv.style.display === 'none' ? 'block' : 'none';
                };
                itemDiv.appendChild(arrayContainer);

                var childrenDiv = document.createElement("div");
                childrenDiv.style.display = 'block';  // Expanded by default
                itemDiv.appendChild(childrenDiv);

                // Render array elements
                value.forEach(function(element, index) {
                    var elem = createElement(index.toString(), element, level + 1);
                    childrenDiv.appendChild(elem);
                });
            } else if (typeof value === 'object' && value !== null) {
                // It's an object. Display its properties.
                var objectName = value.event_type || "Object";  // Use the event_type as the object name if available.

                // Create a clickable line for collapsing/expanding
                var toggleLine = document.createElement("div");
                toggleLine.className = 'toggle-line';
                toggleLine.style.marginLeft = (level * 20) + 'px';
                toggleLine.textContent = objectName + ' {' + Object.keys(value).length + '}';
                toggleLine.onclick = function() {
                    var childrenDiv = this.nextElementSibling;
                    childrenDiv.style.display = childrenDiv.style.display === 'none' ? 'block' : 'none';
                };
                itemDiv.appendChild(toggleLine);

                var childrenDiv = document.createElement("div");
                childrenDiv.style.display = 'block';  // Expanded by default
                itemDiv.appendChild(childrenDiv);

                // Recursive call for child properties
                Object.keys(value).forEach(function(childKey) {
                    var childElem = createElement(childKey, value[childKey], level + 1);
                    childrenDiv.appendChild(childElem);
                });
            } else {
                // For primitives, directly display the value
                var valueSpan = document.createElement("span");
                valueSpan.textContent = JSON.stringify(value);
                valueSpan.className = (typeof value === 'number') ? 'number-value' : 'string-value';
                itemDiv.appendChild(valueSpan);
            }

            return itemDiv;
        }

        keys.forEach(function(key) {
            var value = jsonObj[key];
            var elem = createElement(key, value, 0);  // Level 0 for top-level elements
            container.appendChild(elem);
        });
    }
    """

    div_id = f"json-div-{hash(formatted_json)}"
    html = f"<div id='{div_id}'></div>"  # Removed style affecting overflow and height

    css = """
    <style>
        .string-value { color: #4BAEA0; } /* Pastel green */
        .number-value { color: #5A77FF; } /* Pastel blue */
        .null-value { color: #FFD97D; }   /* Pastel orange */
        .key-text { color: #B565A7; font-weight: bold; } /* Pastel purple */
        .toggle-line { cursor: pointer; }
        /* Removed styles for the scrollbar */
    </style>
    """
    js += f"""
    var container = document.getElementById("{div_id}");
    var jsonObj = {formatted_json};
    createCollapsible(jsonObj, container);
    """

    display(HTML(css + html))  # Include CSS styles in the HTML output
    display(Javascript(js))

# %%
from utils import root_directory
root_dir = root_directory()
file_path_raw_json = f'{root_dir}/datasets/golden_source_logs/2023-10-20_14:32:07.log.json'
file_path_parsed_json = f'{root_dir}/datasets/golden_source_logs/parsed_jsons/2023-10-20_14:32:07.log.json'
# pretty_print_json(file_path)
pretty_print_json_no_scroll(file_path_parsed_json)
# Out:
#     <style>
#         .string-value { color: #4BAEA0; } /* Pastel green */
#         .number-value { color: #5A77FF; } /* Pastel blue */
#         .null-value { color: #FFD97D; }   /* Pastel orange */
#         .key-text { color: #B565A7; font-weight: bold; } /* Pastel purple */
#         .toggle-line { cursor: pointer; }
#         /* Removed styles for the scrollbar */
#     </style>
#     <div id='json-div-6326464176445014485'></div>

# %% [markdown]
# ## raw Json with retrieved chunks

# %%
pretty_print_json_no_scroll(file_path_parsed_json)
# Out:
#     <style>
#         .string-value { color: #4BAEA0; } /* Pastel green */
#         .number-value { color: #5A77FF; } /* Pastel blue */
#         .null-value { color: #FFD97D; }   /* Pastel orange */
#         .key-text { color: #B565A7; font-weight: bold; } /* Pastel purple */
#         .toggle-line { cursor: pointer; }
#         /* Removed styles for the scrollbar */
#     </style>
#     <div id='json-div-6326464176445014485'></div>
